# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


import logging
logging.basicConfig(level=logging.INFO)

# %%
from formula1.peprocessing_newrace import create_new_results, create_new_driverstandings

# %%
from formula1.preprocessing_newdata import read_data

# %%
x = read_data()
# Out:
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.050235

# %%
test = create_new_results()
# Out:
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.050973
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.048494

# %%
test
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# 5             6      18         6              3      8    13        6
# 6             7      18         7              5     14    17        7
# 7             8      18         8              6      1    15        8
# 8             9      18         9              2      4     2       \N
# 9            10      18        10              7     12    18       \N
# 10           11      18        11              8     18    19       \N
# 11           12      18        12              4      6    20       \N
# ...

# %%
test1 = create_new_driverstandings()

# %%
test1
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# 5                      6      18         6     3.0         6            6
# 6                      7      18         7     2.0         7            7
# 7                      8      18         8     1.0         8            8
# 8                      9      19         1    14.0         1            1
# 9                     10      19         2    11.0         3            3
# 10                    11      19         3     6.0         6            6
# 11                    12      19         4     6.0         7            7
# ...

# %% [markdown]
# # Get full new dataset

# %%
from formula1.preprocessing_newdata_newrace import get_clean_app_df

# %%
test = get_clean_app_df()
# Out:
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.062456
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.051328
# INFO:formula1.utils:[merge_constructors] shape=(24317, 19),  time=0:00:00.010066
# INFO:formula1.utils:[merge_drivers     ] shape=(24317, 27),  time=0:00:00.014928
# INFO:formula1.utils:[merge_races       ] shape=(24317, 34),  time=0:00:00.018519
# INFO:formula1.utils:[merge_status      ] shape=(24317, 35),  time=0:00:00.013641
# INFO:formula1.utils:[merge_driverstandi] shape=(24317, 40),  time=0:00:00.071362
# INFO:formula1.utils:[remove_columns    ] shape=(24317, 30),  time=0:00:00.019896
# INFO:formula1.utils:[rename_columns    ] shape=(24317, 30),  time=0:00:00.006565
# INFO:formula1.utils:[sort_races        ] shape=(24317, 30),  time=0:00:00.007007
# INFO:formula1.utils:[average_finishing ] shape=(24317, 31),  time=0:00:00.472452
# INFO:formula1.utils:[average_finishing_] shape=(24317, 32),  time=0:00:04.251821
# ...
