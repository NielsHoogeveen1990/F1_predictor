# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


import logging
logging.basicConfig(level=logging.INFO)

# %%
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
def merge_drivers(df):
    drivers = pd.read_csv('../data/drivers.csv',encoding='ISO-8859-1')
    return df.merge(drivers, left_on='driverId', right_on='driverId')

# %%
driverstandings = pd.read_csv('../data/driverStandings.csv')

# %%
driverstandings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
driverstandings.columns
# Out:
# Index(['driverStandingsId', 'raceId', 'driverId', 'points', 'position', 'positionText', 'wins'], dtype='object')

# %%
constructors['constructorRef'].nunique()
# Out:
# 208

# %%
constructors.describe()
# Out:
#        constructorId  Unnamed: 5
# count     208.000000         0.0
# mean      105.514423         NaN
# std        60.763498         NaN
# min         1.000000         NaN
# 25%        53.750000         NaN
# 50%       105.500000         NaN
# 75%       157.250000         NaN
# max       210.000000         NaN

# %% [markdown]
# # 1. Results

# %%
def read_new_data():
    names = ['resultId', 
                  'raceId', 
                  'driverId', 
                  'constructorId', 
                  'number', 
                  'grid', 
                  'position',
                  'positionText', 
                  'positionOrder', 
                  'points', 
                  'laps', 
                  'time', 
                  'milliseconds', 
                  'fastestLap', 
                  'rank', 
                  'fastestLapTime', 
                  'fastestLapSpeed', 
                  'statusId']
    return pd.read_csv('../new_data/results.csv', names = names)

# %% [markdown]
# # 2. Constructors

# %%
@log_step
def merge_constructors(df):
    constructors = pd.read_csv('../data/constructors.csv')
    return df.merge(constructors[['constructorId','constructorRef']], left_on='constructorId', right_on='constructorId')

# %%
def merge_constructors(df):
    names = ['constructorId', 
                  'constructorRef', 
                  'name', 
                  'nationality', 
                  'url']
    constructors = pd.read_csv('../new_data/constructors.csv', names = names)
    return df.merge(constructors[['constructorId','constructorRef']], left_on='constructorId', right_on='constructorId')

# %% [markdown]
# # 3. Drivers

# %%
['driverId', 'driverRef', 'number', 'code', 'forename', 'surname', 'dob', 'nationality', 'url']

# %%
def merge_drivers(df):
    names = ['driverId',
             'driverRef',
             'number',
             'code',
             'forename',
             'surname',
             'dob',
             'nationality',
             'url']
    
    drivers = pd.read_csv('../new_data/drivers.csv', encoding='ISO-8859-1', names = names)
    return df.merge(drivers, left_on='driverId', right_on='driverId')

# %% [markdown]
# # 4. Races

# %%
['raceId', 'year', 'round', 'circuitId', 'name', 'date', 'time', 'url']

# %%
@log_step
def merge_races(df):
    names = ['raceId',
             'year',
             'round',
             'circuitId',
             'name',
             'date',
             'time',
             'url']
    
    races = pd.read_csv('../new_data/races.csv', names = names)
    return df.merge(races, left_on='raceId', right_on='raceId')

# %%
races = pd.read_csv('../new_data/races.csv')

# %%
races.head()
# Out:
#    1  2009  1.1  1.2 Australian Grand Prix  2009-03-29  06:00:00 http://en.wikipedia.org/wiki/2009_Australian_Grand_Prix
# 0  2  2009    2    2  Malaysian Grand Prix  2009-04-05  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 1  3  2009    3   17    Chinese Grand Prix  2009-04-19  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 2  4  2009    4    3    Bahrain Grand Prix  2009-04-26  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 3  5  2009    5    4    Spanish Grand Prix  2009-05-10  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...
# 4  6  2009    6    6     Monaco Grand Prix  2009-05-24  12:00:00  http://en.wikipedia.org/wiki/2009_Monaco_Grand...

# %% [markdown]
# # 5. Status

# %%
['statusId', 'status']

# %%
@log_step
def merge_status(df):
    names = ['statusId',
             'status']
    
    status = pd.read_csv('../new_data/status.csv', names=names)
    return df.merge(status, left_on='statusId', right_on = 'statusId')

# %% [markdown]
# # 6. Driverstandings

# %%
names = ['driverStandingsId', 'raceId', 'driverId', 'points', 'position', 'positionText', 'wins']

# %%
ds = pd.read_csv('../new_data/driver_standings.csv', names=names)

# %%
names = ['driverStandingsId',
             'raceId',
             'driverId',
             'points',
             'position',
             'positionText',
             'wins']

driverstandings = pd.read_csv('../new_data/driver_standings.csv', names=names)

# %%
driverstandings.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
ds.dtypes
# Out:
# driverStandingsId      int64
# raceId                 int64
# driverId               int64
# points               float64
# position               int64
# positionText          object
# wins                   int64
# dtype: object

# %%
@log_step
def merge_driverstandings(df):
    names = ['driverStandingsId',
             'raceId',
             'driverId',
             'points',
             'position',
             'positionText',
             'wins']
    
    driverstandings = pd.read_csv('../data/driverStandings.csv', names = names)
    return df.merge(driverstandings, how='left', left_on=['raceId','driverId'], right_on = ['raceId','driverId'], suffixes=['_1','_2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-a6ef6857ce37> in <module>
# ----> 1 @log_step
#       2 def merge_driverstandings(df):
#       3     names = ['driverStandingsId',
#       4              'raceId',
#       5              'driverId',
#
# NameError: name 'log_step' is not defined

# %%
@log_step
def merge_driverstandings(df):
    driverstandings = pd.read_csv('../data/driverStandings.csv')
    return df.merge(driverstandings, how='left', left_on=['raceId','driverId'], right_on = ['raceId','driverId'], suffixes=['_1','_2'])

# %% [markdown]
# # Pipe test

# %%
from formula1 import preprocessing_newdata

# %%
work_df = (
    preprocessing_newdata.read_data()
    .pipe(preprocessing_newdata.merge_constructors)
    .pipe(preprocessing_newdata.merge_drivers)
    .pipe(preprocessing_newdata.merge_races)
    .pipe(preprocessing_newdata.merge_status)
    .pipe(preprocessing_newdata.merge_driverstandings)
    .pipe(preprocessing_newdata.remove_columns)
    .pipe(preprocessing_newdata.rename_columns)
    .pipe(preprocessing_newdata.sort_races)
    .pipe(preprocessing_newdata.average_finishing)
    .pipe(preprocessing_newdata.average_finishing_percircuit)
    .pipe(preprocessing_newdata.result_previous_race)
    .pipe(preprocessing_newdata.mean_last_5races)
    .pipe(preprocessing_newdata.last_race_at_circuit)
    .pipe(preprocessing_newdata.get_wins)
    .pipe(preprocessing_newdata.get_wins_per_circuit)
    .pipe(preprocessing_newdata.get_poles)
    .pipe(preprocessing_newdata.get_poles_per_circuit)
    .pipe(preprocessing_newdata.get_total_wins)
    .pipe(preprocessing_newdata.current_wins_inyear)
    .pipe(preprocessing_newdata.get_total_poles)
    .pipe(preprocessing_newdata.get_podiums)
    .pipe(preprocessing_newdata.get_total_podiums)
    .pipe(preprocessing_newdata.get_podiums_per_circuit)
    .pipe(preprocessing_newdata.change_datetime)
    .pipe(preprocessing_newdata.get_driver_age)
    .pipe(preprocessing_newdata.get_career_years)
    .pipe(preprocessing_newdata.get_DNF)
    .pipe(preprocessing_newdata.get_DNF_last5races)
    .pipe(preprocessing_newdata.racecounter_per_driver)
    .pipe(preprocessing_newdata.last_race)
    .pipe(preprocessing_newdata.current_championshipstanding)
    .pipe(preprocessing_newdata.remove_remaining_columns)
    .pipe(preprocessing_newdata.get_combinations)
    .pipe(preprocessing_newdata.filter_combinations)
    #.pipe(preprocessing_newdata.new_race)
    #.pipe(preprocessing_newdata.get_total_races)
    .pipe(preprocessing_newdata.get_winning_driver)
    .pipe(preprocessing_newdata.get_final_dataset)
    .pipe(preprocessing_newdata.fill_na_rows)
    .pipe(preprocessing_newdata.drop_na_rows)
)
# Out:
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.083903
# INFO:formula1.utils:[merge_constructors] shape=(24297, 19),  time=0:00:00.021721
# INFO:formula1.utils:[merge_drivers     ] shape=(24297, 27),  time=0:00:00.017250
# INFO:formula1.utils:[merge_races       ] shape=(24297, 34),  time=0:00:00.019191
# INFO:formula1.utils:[merge_status      ] shape=(24297, 35),  time=0:00:00.013032
# INFO:formula1.utils:[merge_driverstandi] shape=(24297, 40),  time=0:00:00.038858
# INFO:formula1.utils:[remove_columns    ] shape=(24297, 30),  time=0:00:00.019630
# INFO:formula1.utils:[rename_columns    ] shape=(24297, 30),  time=0:00:00.006667
# INFO:formula1.utils:[sort_races        ] shape=(24297, 30),  time=0:00:00.006830
# INFO:formula1.utils:[average_finishing ] shape=(24297, 31),  time=0:00:00.483592
# INFO:formula1.utils:[average_finishing_] shape=(24297, 32),  time=0:00:04.278835
# INFO:formula1.utils:[result_previous_ra] shape=(24297, 33),  time=0:00:00.005388
# ...

# %%
work_df
# Out:
#        constructorRef_left  mean_position_till_date_left  \
# 3957                  alfa                      7.857143
# 3963                  alfa                      7.857143
# 3966                  alfa                      7.857143
# 3968                  alfa                      7.857143
# 3970                  alfa                      7.857143
# 3973                  alfa                      7.857143
# 3977                  alfa                      4.166667
# 3984                  alfa                      4.166667
# 3987                  alfa                      4.166667
# 3989                  alfa                      4.166667
# 3991                  alfa                      4.166667
# 3994                  alfa                      4.166667
# 4103               ferrari                      8.600000
# 4104               ferrari                      8.600000
# 4113               ferrari                      8.600000
# ...

# %% [markdown]
# # Get clean DF

# %%
from formula1.preprocessing_newdata import get_clean_df

# %%
df = get_clean_df()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-67ef87d236bb> in <module>
# ----> 1 df = get_clean_df()
#
# ~/Desktop/Projects/formula1/formula1/preprocessing_newdata.py in get_clean_df()
#     441
#     442 def get_clean_df():
# --> 443     return (read_data()
#     444     .pipe(merge_constructors)
#     445     .pipe(merge_drivers)
#
# ~/Desktop/Projects/formula1/formula1/utils.py in wrapper(*args, **kwargs)
#       9         func_name = func.__name__[:str_length]
#      10         tic = dt.datetime.now()
# ---> 11         result = func(*args, **kwargs)
#      12         time_taken = str(dt.datetime.now() - tic)
#      13         logger.info(f"[{func_name: <{str_length}}] shape={result.shape},  time={time_taken}")
#
# ~/Desktop/Projects/formula1/formula1/preprocessing_newdata.py in read_data()
#      23              'fastestLapSpeed',
# ...

# %%
df.shape
# Out:
# (284894, 37)

# %%
df_retrain = get_clean_df_retrain()
# Out:
# INFO:formula1.utils:[read_data         ] shape=(24297, 18),  time=0:00:00.071989
# INFO:formula1.utils:[merge_constructors] shape=(24297, 19),  time=0:00:00.021359
# INFO:formula1.utils:[merge_drivers     ] shape=(24297, 27),  time=0:00:00.018928
# INFO:formula1.utils:[merge_races       ] shape=(24297, 34),  time=0:00:00.020237
# INFO:formula1.utils:[merge_status      ] shape=(24297, 35),  time=0:00:00.016466
# INFO:formula1.utils:[merge_driverstandi] shape=(24297, 40),  time=0:00:00.045588
# INFO:formula1.utils:[remove_columns    ] shape=(24297, 30),  time=0:00:00.021245
# INFO:formula1.utils:[rename_columns    ] shape=(24297, 30),  time=0:00:00.007625
# INFO:formula1.utils:[sort_races        ] shape=(24297, 30),  time=0:00:00.007336
# INFO:formula1.utils:[average_finishing ] shape=(24297, 31),  time=0:00:00.499736
# INFO:formula1.utils:[average_finishing_] shape=(24297, 32),  time=0:00:04.506129
# INFO:formula1.utils:[result_previous_ra] shape=(24297, 33),  time=0:00:00.005240
# ...

# %%
df_retrain.shape
# Out:
# (284894, 37)

# %%
df_retrain.dtypes
# Out:
# constructorRef_left                           object
# mean_position_till_date_left                 float64
# mean_position__percircuit_till_date_left     float64
# result_previous_race_left                    float64
# mean_last5_races_left                        float64
# win_per_circuit_left                         float64
# poles_per_circuit_left                       float64
# total_wins_left                              float64
# wins_this_year_cumulative_left               float64
# total_poles_left                             float64
# total_podiums_left                           float64
# podium_per_circuit_left                      float64
# current_age_years_left                       float64
# career_years_left                              int64
# dnf_last5_left                               float64
# race_count_left                                int64
# championship_standing_before_race_left       float64
# constructorRef_right                          object
# ...

# %%
import sqlite3
from contextlib import closing
import os
import pandas as pd

from formula1.preprocessing_newdata import get_clean_app_df


# Create a database
def db_connection():
    sqlite_db = sqlite3.connect('db/f1.sqlite') #switch to path: db/f1.sqlite for the app
    return sqlite_db


def fill_db():
    df = get_clean_app_df()
    db_conn = db_connection()
    df.to_sql('f1_races', db_conn, if_exists='replace', index=False)


def run_query(db_conn, query, *args):
    with closing(db_conn.cursor()) as cursor:
        result = cursor.execute(query, args).fetchall()
        db_conn.commit() #commit actually pushes the changes to the database
    return result


# def retrieve_race_data(driver1, driver2, circuit, year):
#     db_conn = db_connection()
#     result = run_query(db_conn,f'SELECT * FROM f1_races '
#     f'WHERE (driverRef_left = "{driver1}" '
#     f'AND driverRef_right= "{driver2}" '
#     f'AND name_left= "{circuit}" '
#     f'AND year_left= "{year}") ')
#
#     return result


def retrieve_prediction_data(driver1, driver2, circuit, year):
    db_conn = db_connection()
    #result = run_query(db_conn,f'SELECT * FROM f1_races WHERE (constructorRef_left = "{constructor}" AND year_left= "{year}") ')

    return pd.read_sql(f'SELECT * FROM f1_races'
                       f' WHERE (driverRef_left = "{driver1}" '
                       f'AND driverRef_right= "{driver2}" '
                       f'AND name_left= "{circuit}" '
                       f'AND year_left= "{year}" ) ', db_conn)



def retrieve_prediction_data_race(circuit, year):
    db_conn = db_connection()
    #result = run_query(db_conn,f'SELECT * FROM f1_races WHERE (constructorRef_left = "{constructor}" AND year_left= "{year}") ')

    return pd.read_sql(f'SELECT * FROM f1_races'
                       f' WHERE (name_left = "{circuit}" '
                       f'AND year_left= "{year}" ) ', db_conn)

# %%
df.head()
# Out:
#      constructorRef_left  mean_position_till_date_left  mean_position__percircuit_till_date_left  result_previous_race_left  mean_last5_races_left  win_per_circuit_left  poles_per_circuit_left  total_wins_left  wins_this_year_cumulative_left  total_poles_left  total_podiums_left  podium_per_circuit_left  current_age_years_left  career_years_left  dnf_last5_left  race_count_left  championship_standing_before_race_left constructorRef_right  mean_position_till_date_right  \
# 3957                alfa                      7.857143                                      12.0                       15.0                    8.4                   0.0                     1.0              3.0                             0.0               4.0                 3.0                      0.0                     NaN                  1             3.0                8                                     2.0                 alfa                       4.166667
# ...

# %%
from formula1.preprocessing import get_clean_df

# %% [markdown]
# df_old = get_clean_df()

# %%
df_old.shape
# Out:
# (278746, 37)

# %%
df_old.head()
# Out:
#      constructorRef_left  mean_position_till_date_left  mean_position__percircuit_till_date_left  result_previous_race_left  mean_last5_races_left  win_per_circuit_left  poles_per_circuit_left  total_wins_left  wins_this_year_cumulative_left  total_poles_left  total_podiums_left  podium_per_circuit_left  current_age_years_left  career_years_left  dnf_last5_left  race_count_left  championship_standing_before_race_left constructorRef_right  mean_position_till_date_right  \
# 3957                alfa                      7.857143                                      12.0                       15.0                    8.4                   0.0                     1.0              3.0                             0.0               4.0                 3.0                      0.0                39.92416                  1             3.0                8                                     2.0                 alfa                       4.166667
# ...

# %% [markdown]
# # Read from SQL DB

# %%
import sqlite3

# %%
sqlite_db = sqlite3.connect('../db/f1.sqlite')

# %%
from formula1.db import db_connection, retrieve_prediction_data, retrieve_prediction_data_race

# %%
test = retrieve_prediction_data_race('Spanish Grand Prix', 2019)

# %%
test.shape
# Out:
# (240, 41)

# %%
assert test[test['driverRef_left'] == 'vettel']['last_race_at_circuit_left'].values[0]==4

# %%
df_predict = test.drop(['driverRef_left', 'name_left', 'driverRef_right', 'leftwon', 'year_left'], axis=1)

# %%
df_predict.dtypes
# Out:
# constructorRef_left                           object
# mean_position_till_date_left                 float64
# mean_position__percircuit_till_date_left     float64
# result_previous_race_left                    float64
# mean_last5_races_left                        float64
# win_per_circuit_left                         float64
# poles_per_circuit_left                       float64
# total_wins_left                              float64
# wins_this_year_cumulative_left               float64
# total_poles_left                             float64
# total_podiums_left                           float64
# podium_per_circuit_left                      float64
# current_age_years_left                        object
# career_years_left                              int64
# dnf_last5_left                               float64
# race_count_left                                int64
# championship_standing_before_race_left       float64
# constructorRef_right                          object
# ...

# %%
df_predict.corr()
# Out:
#                                            mean_position_till_date_left  mean_position__percircuit_till_date_left  result_previous_race_left  mean_last5_races_left  win_per_circuit_left  poles_per_circuit_left  total_wins_left  wins_this_year_cumulative_left  total_poles_left  total_podiums_left  podium_per_circuit_left  career_years_left  dnf_last5_left  race_count_left  championship_standing_before_race_left  mean_position_till_date_right  mean_position__percircuit_till_date_right  \
# mean_position_till_date_left                                   1.000000                                  0.705827                   0.614312               0.732863             -0.752404               -0.585329        -0.790727                       -0.567312         -0.765450           -0.864535                -0.853606          -0.587230        0.462027        -0.658186                                0.612804                      -0.066667                                  -0.047055
# ...

# %%
def merge_drivers(df):
    names = ['driverId',
             'driverRef',
             'number',
             'code',
             'forename',
             'surname',
             'dob',
             'nationality',
             'url']

    drivers = pd.read_csv('new_data/driver.csv', encoding='ISO-8859-1', names = names)
    return df.merge(drivers, left_on='driverId', right_on='driverId')

# %%
names = ['driverId',
             'driverRef',
             'number',
             'code',
             'forename',
             'surname',
             'dob',
             'nationality',
             'url']

# %%
drivers = pd.read_csv('../new_data/driver.csv', encoding='ISO-8859-1', names = names)

# %%
drivers.dtypes
# Out:
# driverId        int64
# driverRef      object
# number         object
# code           object
# forename       object
# surname        object
# dob            object
# nationality    object
# url            object
# dtype: object

# %%
drivers
# Out:
#      driverId           driverRef number code    forename        surname         dob    nationality                                                url
# 0           1            hamilton     44  HAM       Lewis       Hamilton  1985-01-07        British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1           2            heidfeld     \N  HEI        Nick       Heidfeld  1977-05-10         German         http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2           3             rosberg      6  ROS        Nico        Rosberg  1985-06-27         German          http://en.wikipedia.org/wiki/Nico_Rosberg
# 3           4              alonso     14  ALO    Fernando         Alonso  1981-07-29        Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 4           5          kovalainen     \N  KOV      Heikki     Kovalainen  1981-10-19        Finnish     http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ...

# %%
old_drivers = pd.read_csv('../data/drivers.csv',encoding='ISO-8859-1')

# %%
old_drivers
# Out:
#      driverId           driverRef  number code    forename        surname         dob    nationality                                                url
# 0           1            hamilton    44.0  HAM       Lewis       Hamilton  07/01/1985        British        http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1           2            heidfeld     NaN  HEI        Nick       Heidfeld  10/05/1977         German         http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2           3             rosberg     6.0  ROS        Nico        Rosberg  27/06/1985         German          http://en.wikipedia.org/wiki/Nico_Rosberg
# 3           4              alonso    14.0  ALO    Fernando         Alonso  29/07/1981        Spanish       http://en.wikipedia.org/wiki/Fernando_Alonso
# 4           5          kovalainen     NaN  KOV      Heikki     Kovalainen  19/10/1981        Finnish     http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ...

# %%
def change_datetime(df):
    return df.assign(
        dob = lambda df: pd.to_datetime(df['dob'], format='%Y-%m-%d', errors='coerce')
    )

# %%
x = change_datetime(drivers)

# %%
x.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-257-af0675901b82> in <module>
# ----> 1 x.dtype
#
# ~/Desktop/Projects/formula1/venv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
